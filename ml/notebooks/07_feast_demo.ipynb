# %% [markdown]
# # 07 · Feast feature store demo
#
# Materialize and fetch features via the Feast repo in `ml/feature_repo/`.

# %%
import sys, pathlib
# Make the ml-prediction package importable from the repo root.
REPO = pathlib.Path.cwd()
while REPO != REPO.parent and not (REPO / 'ml' / 'data' / 'training.csv').exists():
    REPO = REPO.parent
sys.path.insert(0, str(REPO / 'apps' / 'ml-prediction' / 'src'))
DATA = REPO / 'ml' / 'data' / 'training.csv'

# %%
# The Feast repo defines an entity (segment) and a FeatureView over
# the engineered features. Apply it from the repo directory:
#   cd ml/feature_repo && feast apply
import pathlib
print((REPO / 'ml' / 'feature_repo' / 'feature_store.yaml').read_text())

# %% [markdown]
# Online features (Redis) serve the live API; offline features (the parquet/Postgres source) feed training — the same definitions, one source of truth.
