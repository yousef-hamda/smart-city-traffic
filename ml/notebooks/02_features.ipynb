# %% [markdown]
# # 02 · Feature Engineering
#
# The time + lag features the models consume.

# %%
import sys, pathlib
# Make the ml-prediction package importable from the repo root.
REPO = pathlib.Path.cwd()
while REPO != REPO.parent and not (REPO / 'ml' / 'data' / 'training.csv').exists():
    REPO = REPO.parent
sys.path.insert(0, str(REPO / 'apps' / 'ml-prediction' / 'src'))
DATA = REPO / 'ml' / 'data' / 'training.csv'

# %%
import pandas as pd
from ml_prediction.models.demand import FEATURES
df = pd.read_csv(DATA)
print('Model features:', FEATURES)
[c for c in FEATURES if c in df.columns]

# %% [markdown]
# Lag and rolling features capture autocorrelation (traffic now predicts traffic soon); calendar features capture the weekly rhythm.

# %%
present = [c for c in FEATURES if c in df.columns]
df[present].corr()
